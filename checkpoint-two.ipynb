# %% [markdown]
# # Checkpoint Two: Exploratory Data Analysis
#
# Now that your chosen dataset is approved, it is time to start working on your analysis. Use this notebook to perform your EDA and make notes where directed to as you work.
#
# ## Getting Started
#
# Since we have not provided your dataset for you, you will need to load the necessary files in this repository. Make sure to include a link back to the original dataset here as well.
#
# My dataset:
#
# Your first task in EDA is to import necessary libraries and create a dataframe(s). Make note in the form of code comments of what your thought process is as you work on this setup task.

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
plt.rcParams['figure.figsize'] = (20,10)


df = pd.read_csv('DEI Dataset.csv')
questionsdf = pd.read_csv('Sheet 1-Table 1.csv')
pd.set_option('display.max_columns', None)
df.head(20)
# Out:
#     Id       Name    Surname    Division Manager                     Gender  \
# 0    1    Deborah    Addison          IT      No                Transgender
# 1    2       Mona       Hill   Marketing      No                       Male
# 2    3   Kimberly    Shelton     Finance      No                     Female
# 3    4      Denis   Robinson          HR      No                       Male
# 4    5     Carmen       Gunn          RD      No                       Male
# 5    6     Nathan    Furnell       Sales      No                       Male
# 6    7       Luke   Sinclair   Marketing      No                       Male
# 7    8       Fred     Callan       Sales      No                       Male
# 8    9     Carter       Owen     Finance      No                       Male
# 9   10      Harry     Dobson       Sales      No                       Male
# 10  11      Ramon     Mccall       Sales      No                       Male
# ...

# %% [markdown]
# ## Get to Know the Numbers
#
# Now that you have everything setup, put any code that you use to get to know the dataframe and its rows and columns better in the cell below. You can use whatever techniques you like, except for visualizations. You will put those in a separate section.
#
# When working on your code, make sure to leave comments so that your mentors can understand your thought process.

# %%
print(df.columns.values)
# Out:
# ['Id' 'Name' 'Surname' 'Division' 'Manager' 'Gender' 'Sexual_Orientation'
#  'LGBTQ' 'Indigenous' 'Ethnicity' 'Disability' 'Minority' 'Veteran'
#  'Date of Birth' 'Age' 'Preferred Name' 'Nationality' 'Hobbies' 'Pronouns'
#  'Mobile Number' 'Email' 'Aug_D_Q1' 'Aug_D_Q2' 'Aug_D_Q3' 'Aug_D_Q4'
#  'Aug_D_Q5' 'D_Negative' 'D_Neutral' 'D_Positive' 'Aug_E_Q1' 'Aug_E_Q2'
#  'Aug_E_Q3' 'Aug_E_Q4' 'Aug_E_Q5' 'E_Negative' 'E_Neutral' 'E_Positive'
#  'Aug_I_Q1' 'Aug_I_Q2' 'Aug_I_Q3' 'Aug_I_Q4' 'Aug_I_Q5' 'I_Negative'
#  'I_Neutral' 'I_Positive']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  10000 non-null  int64
#  1   Name                10000 non-null  object
#  2   Surname             10000 non-null  object
#  3   Division            10000 non-null  object
#  4   Manager             10000 non-null  object
#  5   Gender              10000 non-null  object
#  6   Sexual_Orientation  10000 non-null  object
#  7   LGBTQ               10000 non-null  object
#  8   Indigenous          10000 non-null  object
#  9   Ethnicity           10000 non-null  object
#  10  Disability          10000 non-null  object
#  11  Minority            10000 non-null  object
#  12  Veteran             10000 non-null  object
#  13  Date of Birth       10000 non-null  object
#  14  Age                 10000 non-null  int64
# ...

# %%
df_2 = df.drop(['Name', 'Surname', 'Preferred Name', 'Mobile Number', 'Email', 'Date of Birth'], axis=1)
df_2.shape
# Out:
# (10000, 39)

# %% [markdown]
# I ran duplicates and found that there were no duplicate rows to drop.

# %%
df_2.drop_duplicates()
# Out:
#          Id   Division Manager             Gender Sexual_Orientation  \
# 0         1         IT      No        Transgender       Heterosexual
# 1         2  Marketing      No               Male       Heterosexual
# 2         3    Finance      No             Female       Heterosexual
# 3         4         HR      No               Male       Heterosexual
# 4         5         RD      No               Male       Heterosexual
# ...     ...        ...     ...                ...                ...
# 9995   9996         HR      No               Male       Heterosexual
# 9996   9997      Sales      No               Male       Heterosexual
# 9997   9998      Sales      No               Male       Heterosexual
# 9998   9999    Finance      No  Prefer not to say       Heterosexual
# 9999  10000      Sales      No             Female  Prefer not to say
#
#                   LGBTQ         Indigenous Ethnicity Disability Minority  \
# ...

# %% [markdown]
# ## Visualize
#
# Create any visualizations for your EDA here. Make note in the form of code comments of what your thought process is for your visualizations.

# %%
DEISummary = df_2[["D_Negative","D_Neutral", "D_Positive", "E_Negative","E_Neutral", "E_Positive", "I_Negative","I_Neutral", "I_Positive"]].mean()
# print(DEISummary)

avg_DEI = {"Diversity":[1.5556, 0.7881,2.6563],    
"Equity":[1.2622, 0.6448,3.0930],   
"Inclusion": [1.3638,0.6744,2.9618]   
}

vis_DEI = pd.DataFrame(avg_DEI).T
vis_DEI.plot(kind='bar', color=['maroon', 'green', 'blue'])
plt.xlabel("DEI Category")
plt.ylabel("Mean of Responses")
plt.legend(["Negative", "Neutral", "Positive"])
plt.show()

# %%
df_2['LGBTQ'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Summarize Your Results
#
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# It seems like this data set is covering several different purposes. Initially, it states that the purpose is for assessing and potentially improving company-wide DEI, but there are also questions about hobbies that I find odd. I'm not sure how or why you would want to use those on an analysis "Well, the people who love knitting think we're super sexist!" IDK.
#
# 2. Do you have any concerns about your dataset?
# One concern is just the sheer size. There is usable data here, but I'm thinking I'll have to focus the set to get at some specific (and valid) visualizations.
# I worry that some of these questions might violate the privacy of respondants. I believe this is a thoretical data set, but it a realy company environment, I would question the validity if employees were thinking their responses might lead to unwanted follow up. The DEI questions are subjective, so it is important to attempt to find any responses that seem suspect (for example all one score across all areas). Additionally, even answers given in full personal honesty could vary widely from indiviual to individual. This is where noting trends within smaller groups may be more helpful.
#
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
#     +Birthday is an object format and should be changed to date time.
#     +Not sure it's beneficial to have both Birthday and Age columns? Might omit one from analysis set.
#     +D_Negative, D_Neutral, D_Positive referrs to the number of responses for DIVERSITY questions per respondant. This is the same for EQUITY questions (E_Negative) and Inclusion Questions (I_Negative). I think it will be in my best interest to look at the three categories both separately and as a full group.
#     +Not sure how I will use preferred pronouns and names categories. I want to keep an eye out to see if the DEI questions have any common trends amongst specific groups.
